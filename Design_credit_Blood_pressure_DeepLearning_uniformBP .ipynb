# %%
import zipfile as zf
files = zf.ZipFile("archive.zip", 'r')
files.extractall('directory to extract')
files.close()

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import glob
import os
import matplotlib.pyplot as plt

# %%
# importing libraries
import numpy as np # For numerical computation
import pandas as pd # Data manipulation
import seaborn as sns # plotting
import scipy.io # reading matlab files in python
from scipy import signal #signal processing
from scipy.fftpack import fft, dct #signal processing

from sklearn.linear_model import LinearRegression #linear regression model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, train_test_split # cross validation split
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pyplot as plt # For plotting graphs(Visualization)

import os # system-wide functions

# %%
sample_file = scipy.io.loadmat(f'archive/part_1.mat')
print(f'sample_file Data type: {type(sample_file)}')
print(f'sample_file keys:\n{sample_file.keys()}')
# Out:
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])

# %%
# Loading a sample .mat file to understand the data dimensions
test_sample = scipy.io.loadmat(f'archive/part_1.mat')['p']
print(f'test_sample Data type: {type(test_sample)}')
print(f'test_sample shape/dimensions: {test_sample.shape}')
# Out:
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)

# %%
print(f"Total Samples: {len(test_sample[0])}")
print(f"Number of readings in each sample(column): {len(test_sample[0][0])}")
print(f"Number of samples in each reading(ECG): {len(test_sample[0][0][2])}")

temp_mat = test_sample[0, 999]
temp_length = temp_mat.shape[1]
sample_size = 125


print(temp_length)
print((int)(temp_length/sample_size))
# Out:
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 61000
# 9000
# 72

# %%
temp_mat.shape
# Out:
# (3, 9000)

# %%
sample_size = 125
ppg = []
for i in range(1000):
    temp_mat = test_sample[0, i]
    temp_length = temp_mat.shape[1]
    for j in range((int)(temp_length/sample_size)):
        temp_ppg = temp_mat[0, j*sample_size:(j+1)*sample_size]
        ppg.append(temp_ppg)

# %%
ecg = []
bp = []
sbp = [] #Systolic Blood Pressure
dbp = [] #Diastolic Blood Pressue
size = 125 #sample size

for i in range(1000):
    temp_mat = test_sample[0, i]
    temp_length = temp_mat.shape[1]
    for j in range((int)(temp_length/sample_size)):
        temp_ecg = temp_mat[2, j*size:(j+1)*size]
        temp_bp = temp_mat[1, j*size:(j+1)*size]
        
        max_value = max(temp_bp)
        min_value = min(temp_bp)
        
        sbp.append(max_value)
        dbp.append(min_value)
        ecg.append(temp_ecg)
        bp.append(temp_bp)

# %%
# Reshaping the ecg, ppg and bp signal data into column vectors
ppg, ecg, bp = np.array(ppg).reshape(-1,1), np.array(ecg).reshape(-1,1), np.array(bp).reshape(-1,1)
sbp, dbp = np.array(sbp).reshape(-1,1), np.array(dbp).reshape(-1,1)
print(f'PPG_shape: {ppg.shape}\n ECG_shape: {ecg.shape}\n BP_shape: {bp.shape}')
print(f'Systolic-BP_shape: {sbp.shape},\n Diastolic-BP_shape: {dbp.shape}')
# Out:
# PPG_shape: (32061000, 1)
#  ECG_shape: (32061000, 1)
#  BP_shape: (32061000, 1)
# Systolic-BP_shape: (256488, 1),
#  Diastolic-BP_shape: (256488, 1)

# %%
##plotting sample ppg, ecg and bp signals
##using a sample size of 500
fig, ax = plt.subplots(3,1, figsize=(9,12), sharex=True)

ax[0].set_title('PPG graph', fontsize=16)
ax[0].set_ylabel('Signal Value')
ax[0].plot(ppg[:500])

ax[1].set_title('ECG graph', fontsize=16)
ax[1].set_ylabel('Signal Value')
ax[1].plot(ecg[:500])

ax[2].set_title('Blood Pressure (BP) graph', fontsize=16)
ax[2].set_ylabel('Signal Value')
ax[2].set_xlabel('Sample size')
ax[2].plot(bp[:500])

# %%
Map=(sbp+ (2*dbp))/3

# %%
plt.plot(Map[:500])
plt.xlabel("sample")
plt.ylabel("Map")
# Out:
# Text(0, 0.5, 'Map')

# %%
s=0
size=15*125
e=15*125
necgs=[]
nbps=[]
while(e<len(ecg)):
  necgs.append(ecg[s:e])
  nbps.append(bp[s:e])
  s+=size
  e+=size

# %%
necgs=np.array(necgs)
nbps=np.array(nbps)

# %%
necgs.shape
# Out:
# (17099, 1875, 1)

# %%
nbps.shape
# Out:
# (17099, 1875, 1)

# %%
nbps=nbps.reshape(17099,1875)

# %%
nbps.shape
# Out:
# (17099, 1875)

# %%
necgs=necgs.reshape(17099,1875)

# %%
necgs.shape
# Out:
# (17099, 1875)

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


def run():
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz

    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 500.0
    lowcut = 0.1
    highcut = 50.0
    y = butter_bandpass_filter(necgs[0], lowcut, highcut, fs, order=2)
    plt.plot(y[:500])
    plt.xlabel('sample size')
    plt.grid(True)

    plt.show()


run()

# %%
fs = 500.0
lowcut = 0.1
highcut = 50.0
necgs_new=[]
for i in range(len(necgs)):
  necgs_new.append(butter_bandpass_filter(necgs[i], lowcut, highcut, fs, order=2))

# %%
fig, ax = plt.subplots(2,1, figsize=(9,12), sharex=True)

ax[0].set_title('ecg_new', fontsize=16)
ax[0].set_ylabel('Signal Value')
ax[0].plot(necgs_new[0][:500])

ax[1].set_title('ECG graph', fontsize=16)
ax[1].set_ylabel('Signal Value')
ax[1].plot(necgs[0][:500])

# %%
pip install neurokit2
# Out:
# Requirement already satisfied: neurokit2 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.2.0)
# Requirement already satisfied: matplotlib in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (3.5.2)
# Requirement already satisfied: numpy in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.23.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.1.1)
# Requirement already satisfied: scipy in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.8.1)
# Requirement already satisfied: pandas in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.4.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.0->neurokit2) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.0->neurokit2) (1.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (4.34.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->neurokit2) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.signal
import scipy.stats
import neurokit2 as nk

# %%
necgs_new=np.array(necgs_new)

# %%
necgs_new.shape
# Out:
# (17099, 1875)

# %%
for i in range(len(necgs_new)):
  necgs_new[i]=necgs_new[i].reshape(len(necgs_new[i]))

# %%
for i in range(len(nbps)):
  nbps[i]=nbps[i].reshape(len(nbps[i]))

# %%
necgs_new.shape
# Out:
# (17099, 1875)

# %%
nbps.shape
# Out:
# (17099, 1875)

# %%
final_ecg=[]
final_bp=[]
for i in range(len(necgs_new)):
  _, rpeaks = nk.ecg_peaks(necgs_new[i], sampling_rate=50)
  a=[]
  for j in rpeaks.values():
    a.append(j)
  peak=[]
  peak=a[0]
  avg_d=0
  for j in range(1,len(peak)):
    avg_d+=peak[j]-peak[j-1]

  if len(peak)<=1:
    continue
  avg_d=avg_d/(len(peak)-1)
  flag=1
  for j in range(1,len(peak)):
    d=peak[j]-peak[j-1]
    if(d>avg_d+(0.1*avg_d)):
      flag=0
      break
    if(d<avg_d-(0.1*avg_d)):
      flag=0
      break
  if(flag==1):
    final_bp.append(nbps[i])
    final_ecg.append(necgs_new[i])

# %%
len(final_bp)
# Out:
# 6990

# %%
final_bp=np.array(final_bp)
final_ecg=np.array(final_ecg)

# %%
final_bp.shape
# Out:
# (6990, 1875)

# %%
final_ecg.shape
# Out:
# (6990, 1875)

# %%
plt.plot(final_ecg[6000])

# %%
plt.plot(final_bp[6000])

# %%
from matplotlib.patches import BoxStyle
all_peaks=[]
corr_bp=[]
for i in range(len(final_ecg)):
  e=final_ecg[i]
  bx=final_bp[i]
  _, rpeaks = nk.ecg_peaks(e, sampling_rate=50)
  a=[]
  for j in rpeaks.values():
    a.append(j)
  peak=[]
  peak=a[0]
  ind=0
  while ind+3<len(peak):
    jx=peak[ind]
    k=peak[ind+3]
    temp=e[jx:k+1]
    b=bx[jx:k+1]
    all_peaks.append(temp)
    corr_bp.append(b)
    ind+=4

# %%
len(all_peaks)
# Out:
# 32769

# %%
all_peaks=np.array(all_peaks)
corr_bp=np.array(corr_bp)

# %%
all_peaks.shape
# Out:
# (32769,)

# %%
from scipy import signal
from scipy.fft import fft, fftfreq, fftshift
import scipy.fft
f=scipy.signal.resample(all_peaks[1], 120)
b=scipy.signal.resample(corr_bp[1], 120)

# %%
plt.plot(f)

# %%
f_peak=[]
f_bp=[]
for i in range(len(all_peaks)):
    f=scipy.signal.resample(all_peaks[i], 120)
    b=scipy.signal.resample(corr_bp[i], 120)
    f_peak.append(f);
    f_bp.append(b)

# %%
f_peak=np.array(f_peak)
f_bp=np.array(f_bp)

# %%
f_peak.shape
# Out:
# (32769, 120)

# %%
f_bp.shape
# Out:
# (32769, 120)

# %%
peak_sbp=[]
peak_dbp=[]
for i in f_bp:
  peak_sbp.append(max(i))
  peak_dbp.append(min(i))

# %%
peak_sbp=np.array(peak_sbp)
peak_dbp=np.array(peak_dbp)

# %%
peak_sbp.shape
# Out:
# (32769,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f_peak,peak_sbp, test_size=0.33)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %%
def rmse(y_true, y_pred):
    """Computes the Root Mean Squared Error (RMSE)."""
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def Model(input_dim, activation, num_class):
    model = Sequential()

    model.add(Dense(1024, input_dim = input_dim))
    model.add(Activation(activation))
    model.add(Dropout(0.5))

    model.add(Dense(512)) 
    model.add(Activation(activation))
    model.add(Dropout(0.5))

    model.add(Dense(64))    
    model.add(Activation(activation))
    model.add(Dropout(0.25))

    model.add(Dense(num_class))    
    model.add(Activation('linear'))
    
    model.compile(loss='Huber',
                  optimizer=optimizers.Adam(lr = 0.001),
                  metrics=['MeanAbsoluteError']
                 )
    return model

# %%
input_dim = X_train.shape[1]
activation = 'relu'
classes = 1
model = Model(input_dim=input_dim, activation=activation, num_class=classes)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              123904
#
#  activation (Activation)     (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 64)                32832
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 681,601
# Trainable params: 681,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, # using the first 1million rows for speed.
                    y_train.squeeze(),
                    epochs=100,
                    batch_size=128,
                    verbose = 1
                   )
# Out:
# Epoch 1/100
# 172/172 [==============================] - 2s 7ms/step - loss: 38.8471 - mean_absolute_error: 39.3435
# Epoch 2/100
# 172/172 [==============================] - 1s 7ms/step - loss: 20.5215 - mean_absolute_error: 21.0161
# Epoch 3/100
# 172/172 [==============================] - 1s 7ms/step - loss: 20.2044 - mean_absolute_error: 20.6992
# Epoch 4/100
# 172/172 [==============================] - 1s 7ms/step - loss: 19.6768 - mean_absolute_error: 20.1718
# Epoch 5/100
# 172/172 [==============================] - 1s 7ms/step - loss: 19.4338 - mean_absolute_error: 19.9281
# Epoch 6/100
# 172/172 [==============================] - 1s 7ms/step - loss: 19.4146 - mean_absolute_error: 19.9089
# Epoch 7/100
# 172/172 [==============================] - 1s 7ms/step - loss: 19.1670 - mean_absolute_error: 19.6616
# Epoch 8/100
# 172/172 [==============================] - 1s 7ms/step - loss: 19.0238 - mean_absolute_error: 19.5185
# Epoch 9/100
# 172/172 [==============================] - 1s 7ms/step - loss: 18.8467 - mean_absolute_error: 19.3410
# Epoch 10/100
# 172/172 [==============================] - 1s 7ms/step - loss: 18.7122 - mean_absolute_error: 19.2065
# Epoch 11/100
# 172/172 [==============================] - 2s 9ms/step - loss: 18.4681 - mean_absolute_error: 18.9622
# Epoch 12/100
# 172/172 [==============================] - 1s 8ms/step - loss: 18.5165 - mean_absolute_error: 19.0108
# Epoch 13/100
# 172/172 [==============================] - 1s 8ms/step - loss: 18.4469 - mean_absolute_error: 18.9413
# Epoch 14/100
# 172/172 [==============================] - 1s 7ms/step - loss: 18.3297 - mean_absolute_error: 18.8233
# Epoch 15/100
# 172/172 [==============================] - 1s 7ms/step - loss: 18.1395 - mean_absolute_error: 18.6333
# Epoch 16/100
# 172/172 [==============================] - 1s 8ms/step - loss: 18.0214 - mean_absolute_error: 18.5156
# Epoch 17/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.9561 - mean_absolute_error: 18.4504
# Epoch 18/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.9227 - mean_absolute_error: 18.4167
# Epoch 19/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.8868 - mean_absolute_error: 18.3813
# Epoch 20/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.8385 - mean_absolute_error: 18.3324
# Epoch 21/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.8224 - mean_absolute_error: 18.3162
# Epoch 22/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.5663 - mean_absolute_error: 18.0604
# Epoch 23/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.6378 - mean_absolute_error: 18.1318
# Epoch 24/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.7329 - mean_absolute_error: 18.2264
# Epoch 25/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.6378 - mean_absolute_error: 18.1316
# Epoch 26/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.7616 - mean_absolute_error: 18.2558
# Epoch 27/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.6165 - mean_absolute_error: 18.1108
# Epoch 28/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.4967 - mean_absolute_error: 17.9908
# Epoch 29/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.6857 - mean_absolute_error: 18.1799
# Epoch 30/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.6039 - mean_absolute_error: 18.0978
# Epoch 31/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.4337 - mean_absolute_error: 17.9279
# Epoch 32/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.3510 - mean_absolute_error: 17.8452
# Epoch 33/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.4573 - mean_absolute_error: 17.9513
# Epoch 34/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.5277 - mean_absolute_error: 18.0214
# Epoch 35/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.3102 - mean_absolute_error: 17.8044
# Epoch 36/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.1388 - mean_absolute_error: 17.6329
# Epoch 37/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.2235 - mean_absolute_error: 17.7173
# Epoch 38/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.2140 - mean_absolute_error: 17.7079
# Epoch 39/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.1475 - mean_absolute_error: 17.6413
# Epoch 40/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.0113 - mean_absolute_error: 17.5052
# Epoch 41/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.2481 - mean_absolute_error: 17.7416
# Epoch 42/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.0341 - mean_absolute_error: 17.5275
# Epoch 43/100
# 172/172 [==============================] - 1s 7ms/step - loss: 17.0241 - mean_absolute_error: 17.5177
# Epoch 44/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.1069 - mean_absolute_error: 17.6007
# Epoch 45/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.2966 - mean_absolute_error: 17.7904
# Epoch 46/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.1548 - mean_absolute_error: 17.6484
# Epoch 47/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.9647 - mean_absolute_error: 17.4585
# Epoch 48/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.9751 - mean_absolute_error: 17.4684
# Epoch 49/100
# 172/172 [==============================] - 1s 8ms/step - loss: 17.1123 - mean_absolute_error: 17.6059
# Epoch 50/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.9962 - mean_absolute_error: 17.4899
# Epoch 51/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.7575 - mean_absolute_error: 17.2509
# Epoch 52/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.7519 - mean_absolute_error: 17.2456
# Epoch 53/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.7654 - mean_absolute_error: 17.2586
# Epoch 54/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.7301 - mean_absolute_error: 17.2235
# Epoch 55/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.8494 - mean_absolute_error: 17.3432
# Epoch 56/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.8415 - mean_absolute_error: 17.3355
# Epoch 57/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.8895 - mean_absolute_error: 17.3835
# Epoch 58/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.6634 - mean_absolute_error: 17.1562
# Epoch 59/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.7699 - mean_absolute_error: 17.2629
# Epoch 60/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.6075 - mean_absolute_error: 17.1014
# Epoch 61/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.6780 - mean_absolute_error: 17.1718
# Epoch 62/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.4937 - mean_absolute_error: 16.9872
# Epoch 63/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.6707 - mean_absolute_error: 17.1642
# Epoch 64/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.6421 - mean_absolute_error: 17.1350
# Epoch 65/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.4329 - mean_absolute_error: 16.9264
# Epoch 66/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.6633 - mean_absolute_error: 17.1573
# Epoch 67/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.4257 - mean_absolute_error: 16.9190
# Epoch 68/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.4738 - mean_absolute_error: 16.9669
# Epoch 69/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.4469 - mean_absolute_error: 16.9406
# Epoch 70/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.3588 - mean_absolute_error: 16.8523
# Epoch 71/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.3167 - mean_absolute_error: 16.8103
# Epoch 72/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.4582 - mean_absolute_error: 16.9515
# Epoch 73/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.2928 - mean_absolute_error: 16.7865
# Epoch 74/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.2940 - mean_absolute_error: 16.7873
# Epoch 75/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.3136 - mean_absolute_error: 16.8067
# Epoch 76/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.3727 - mean_absolute_error: 16.8661
# Epoch 77/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.2336 - mean_absolute_error: 16.7276
# Epoch 78/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.3559 - mean_absolute_error: 16.8496
# Epoch 79/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.3943 - mean_absolute_error: 16.8877
# Epoch 80/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.0486 - mean_absolute_error: 16.5419
# Epoch 81/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.1465 - mean_absolute_error: 16.6400
# Epoch 82/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.1652 - mean_absolute_error: 16.6590
# Epoch 83/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.1100 - mean_absolute_error: 16.6031
# Epoch 84/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.0709 - mean_absolute_error: 16.5641
# Epoch 85/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.1156 - mean_absolute_error: 16.6089
# Epoch 86/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.2110 - mean_absolute_error: 16.7046
# Epoch 87/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.0749 - mean_absolute_error: 16.5680
# Epoch 88/100
# 172/172 [==============================] - 1s 8ms/step - loss: 15.8830 - mean_absolute_error: 16.3758
# Epoch 89/100
# 172/172 [==============================] - 1s 7ms/step - loss: 16.0691 - mean_absolute_error: 16.5628
# Epoch 90/100
# 172/172 [==============================] - 1s 8ms/step - loss: 15.9161 - mean_absolute_error: 16.4090
# Epoch 91/100
# 172/172 [==============================] - 1s 8ms/step - loss: 15.9215 - mean_absolute_error: 16.4150
# Epoch 92/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.0211 - mean_absolute_error: 16.5145
# Epoch 93/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.0754 - mean_absolute_error: 16.5690
# Epoch 94/100
# 172/172 [==============================] - 1s 8ms/step - loss: 16.0917 - mean_absolute_error: 16.5850
# Epoch 95/100
# 172/172 [==============================] - 1s 7ms/step - loss: 15.8322 - mean_absolute_error: 16.3253
# Epoch 96/100
# 172/172 [==============================] - 1s 8ms/step - loss: 15.9306 - mean_absolute_error: 16.4236
# Epoch 97/100
# 172/172 [==============================] - 1s 7ms/step - loss: 15.8187 - mean_absolute_error: 16.3122
# Epoch 98/100
# 172/172 [==============================] - 1s 7ms/step - loss: 15.6437 - mean_absolute_error: 16.1367
# Epoch 99/100
# 172/172 [==============================] - 1s 8ms/step - loss: 15.8820 - mean_absolute_error: 16.3753
# Epoch 100/100
# 172/172 [==============================] - 1s 7ms/step - loss: 15.7267 - mean_absolute_error: 16.2205

# %%
#Predicting on the test set using the nn(neural network) model
val_predictions_sbp = model.predict(X_test)
error = rmse(y_test, val_predictions_sbp)
print(f'Neural Net RMSE: {error}')
# Out:
# 338/338 [==============================] - 1s 2ms/step
# Neural Net RMSE: 12.757742688569234

# %%
plt.title('Train loss against mean_absolute_error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.legend(['Loss', 'Mean_absolute_error'])

# %%
# Visualize predicted BP and the True BP
plt.title("===True SBP values Vs Predicted SBP values===")
plt.xlabel('Number of samples taken')
plt.ylabel('SBP values')
plt.plot(y_test[:100]) #only plotting 100 samples
plt.plot(val_predictions_sbp[:100])
plt.legend(['True_SBP', 'Predicted_SBP'])

# %% [markdown]
# #DBP

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f_peak,peak_dbp, test_size=0.33)

# %%
input_dim = X_train.shape[1]
activation = 'relu'
classes = 1
model = Model(input_dim=input_dim, activation=activation, num_class=classes)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1024)              123904
#
#  activation_4 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 64)                32832
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 681,601
# Trainable params: 681,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, # using the first 1million rows for speed.
                    y_train.squeeze(),
                    epochs=100,
                    batch_size=128,
                    verbose = 1
                   )
# Out:
# Epoch 1/100
# 172/172 [==============================] - 2s 7ms/step - loss: 17.2425 - mean_absolute_error: 17.7350
# Epoch 2/100
# 172/172 [==============================] - 1s 7ms/step - loss: 9.4098 - mean_absolute_error: 9.8974
# Epoch 3/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.9826 - mean_absolute_error: 9.4702
# Epoch 4/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.8957 - mean_absolute_error: 9.3836
# Epoch 5/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.7848 - mean_absolute_error: 9.2724
# Epoch 6/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.6987 - mean_absolute_error: 9.1859
# Epoch 7/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.5231 - mean_absolute_error: 9.0100
# Epoch 8/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.5555 - mean_absolute_error: 9.0428
# Epoch 9/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.4739 - mean_absolute_error: 8.9607
# Epoch 10/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.3834 - mean_absolute_error: 8.8708
# Epoch 11/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.4101 - mean_absolute_error: 8.8969
# Epoch 12/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.3117 - mean_absolute_error: 8.7981
# Epoch 13/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.2398 - mean_absolute_error: 8.7261
# Epoch 14/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.2447 - mean_absolute_error: 8.7318
# Epoch 15/100
# 172/172 [==============================] - 1s 8ms/step - loss: 8.2501 - mean_absolute_error: 8.7369
# Epoch 16/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.1484 - mean_absolute_error: 8.6356
# Epoch 17/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.1499 - mean_absolute_error: 8.6362
# Epoch 18/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.1758 - mean_absolute_error: 8.6622
# Epoch 19/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.1702 - mean_absolute_error: 8.6564
# Epoch 20/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.1123 - mean_absolute_error: 8.5986
# Epoch 21/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.0603 - mean_absolute_error: 8.5471
# Epoch 22/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.1272 - mean_absolute_error: 8.6129
# Epoch 23/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.9396 - mean_absolute_error: 8.4259
# Epoch 24/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.8679 - mean_absolute_error: 8.3542
# Epoch 25/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.8871 - mean_absolute_error: 8.3724
# Epoch 26/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.9476 - mean_absolute_error: 8.4337
# Epoch 27/100
# 172/172 [==============================] - 1s 7ms/step - loss: 8.0116 - mean_absolute_error: 8.4972
# Epoch 28/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.9433 - mean_absolute_error: 8.4298
# Epoch 29/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.9421 - mean_absolute_error: 8.4283
# Epoch 30/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.8760 - mean_absolute_error: 8.3622
# Epoch 31/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.7788 - mean_absolute_error: 8.2650
# Epoch 32/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.6879 - mean_absolute_error: 8.1733
# Epoch 33/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.7638 - mean_absolute_error: 8.2499
# Epoch 34/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.6670 - mean_absolute_error: 8.1524
# Epoch 35/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.7651 - mean_absolute_error: 8.2512
# Epoch 36/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.7042 - mean_absolute_error: 8.1897
# Epoch 37/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.6313 - mean_absolute_error: 8.1168
# Epoch 38/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.6247 - mean_absolute_error: 8.1106
# Epoch 39/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.6190 - mean_absolute_error: 8.1050
# Epoch 40/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.5707 - mean_absolute_error: 8.0568
# Epoch 41/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.5814 - mean_absolute_error: 8.0672
# Epoch 42/100
# 172/172 [==============================] - 1s 8ms/step - loss: 7.5938 - mean_absolute_error: 8.0801
# Epoch 43/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.4839 - mean_absolute_error: 7.9683
# Epoch 44/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.4266 - mean_absolute_error: 7.9130
# Epoch 45/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.4193 - mean_absolute_error: 7.9046
# Epoch 46/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.4456 - mean_absolute_error: 7.9311
# Epoch 47/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.3802 - mean_absolute_error: 7.8653
# Epoch 48/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.4248 - mean_absolute_error: 7.9107
# Epoch 49/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.3091 - mean_absolute_error: 7.7949
# Epoch 50/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.4193 - mean_absolute_error: 7.9057
# Epoch 51/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.2170 - mean_absolute_error: 7.7023
# Epoch 52/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.2812 - mean_absolute_error: 7.7661
# Epoch 53/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.1932 - mean_absolute_error: 7.6785
# Epoch 54/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.1904 - mean_absolute_error: 7.6749
# Epoch 55/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.1308 - mean_absolute_error: 7.6158
# Epoch 56/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.0816 - mean_absolute_error: 7.5673
# Epoch 57/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.0313 - mean_absolute_error: 7.5166
# Epoch 58/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.0205 - mean_absolute_error: 7.5049
# Epoch 59/100
# 172/172 [==============================] - 1s 7ms/step - loss: 7.0452 - mean_absolute_error: 7.5308
# Epoch 60/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.9842 - mean_absolute_error: 7.4679
# Epoch 61/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.9203 - mean_absolute_error: 7.4051
# Epoch 62/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.9660 - mean_absolute_error: 7.4517
# Epoch 63/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.8911 - mean_absolute_error: 7.3755
# Epoch 64/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.7912 - mean_absolute_error: 7.2757
# Epoch 65/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.8325 - mean_absolute_error: 7.3170
# Epoch 66/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.8092 - mean_absolute_error: 7.2938
# Epoch 67/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.7254 - mean_absolute_error: 7.2092
# Epoch 68/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.7700 - mean_absolute_error: 7.2538
# Epoch 69/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.6874 - mean_absolute_error: 7.1710
# Epoch 70/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.7112 - mean_absolute_error: 7.1956
# Epoch 71/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.6698 - mean_absolute_error: 7.1542
# Epoch 72/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.6346 - mean_absolute_error: 7.1177
# Epoch 73/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.5847 - mean_absolute_error: 7.0684
# Epoch 74/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.6302 - mean_absolute_error: 7.1147
# Epoch 75/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.5484 - mean_absolute_error: 7.0318
# Epoch 76/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.5499 - mean_absolute_error: 7.0342
# Epoch 77/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.5133 - mean_absolute_error: 6.9969
# Epoch 78/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.5532 - mean_absolute_error: 7.0369
# Epoch 79/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.4698 - mean_absolute_error: 6.9534
# Epoch 80/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.4849 - mean_absolute_error: 6.9683
# Epoch 81/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.4493 - mean_absolute_error: 6.9325
# Epoch 82/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.4333 - mean_absolute_error: 6.9168
# Epoch 83/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3875 - mean_absolute_error: 6.8713
# Epoch 84/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3848 - mean_absolute_error: 6.8678
# Epoch 85/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3531 - mean_absolute_error: 6.8372
# Epoch 86/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3559 - mean_absolute_error: 6.8393
# Epoch 87/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3770 - mean_absolute_error: 6.8601
# Epoch 88/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3381 - mean_absolute_error: 6.8210
# Epoch 89/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.3461 - mean_absolute_error: 6.8295
# Epoch 90/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.2995 - mean_absolute_error: 6.7813
# Epoch 91/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.2835 - mean_absolute_error: 6.7665
# Epoch 92/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.2939 - mean_absolute_error: 6.7764
# Epoch 93/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.2166 - mean_absolute_error: 6.6987
# Epoch 94/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.1563 - mean_absolute_error: 6.6386
# Epoch 95/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.1869 - mean_absolute_error: 6.6695
# Epoch 96/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.1508 - mean_absolute_error: 6.6333
# Epoch 97/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.1746 - mean_absolute_error: 6.6573
# Epoch 98/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.1668 - mean_absolute_error: 6.6491
# Epoch 99/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.0907 - mean_absolute_error: 6.5730
# Epoch 100/100
# 172/172 [==============================] - 1s 7ms/step - loss: 6.1054 - mean_absolute_error: 6.5867

# %%
#Predicting on the test set using the nn(neural network) model
val_predictions_dbp = model.predict(X_test)
error = rmse(y_test, val_predictions_dbp)
print(f'Neural Net RMSE: {error}')
# Out:
# 338/338 [==============================] - 1s 2ms/step
# Neural Net RMSE: 6.338174902260865

# %%
plt.title('Train loss against mean_absolute_error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.legend(['Loss', 'Mean_absolute_error'])

# %%
# Visualize predicted BP and the True BP
plt.title("===True DBP values Vs Predicted DBP values===")
plt.xlabel('Number of samples taken')
plt.ylabel('DBP values')
plt.plot(y_test[:100]) #only plotting 100 samples
plt.plot(val_predictions_dbp[:100])
plt.legend(['True_DBP', 'Predicted_dBP'])

# %%
health_condition = []
category = ["Normal", "Prehypertension", "Hypertension"]
for i in range(len(val_predictions_sbp)):
  if (val_predictions_sbp[i] <= 90 or val_predictions_dbp[i] <= 60):
    health_condition.append(category[0])
  if ((val_predictions_sbp[i] >= 90 and val_predictions_sbp[i] < 120) and (val_predictions_dbp[i] >= 60 and val_predictions_dbp[i] < 79)):
    health_condition.append(category[0])
  if ((val_predictions_sbp[i] >= 120 and val_predictions_sbp[i] < 140) or (val_predictions_dbp[i] >= 80 and val_predictions_dbp[i] < 90)):
    health_condition.append(category[1])
  if ((val_predictions_sbp[i] >= 140 and val_predictions_sbp[i] < 160) or (val_predictions_dbp[i] >= 90 and val_predictions_dbp[i] < 100)):
    health_condition.append(category[2])
  if (val_predictions_sbp[i] >= 160 or val_predictions_dbp[i] >= 100):
    health_condition.append(category[2])
  if (val_predictions_sbp[i] >= 140 and val_predictions_dbp[i] < 90):
    health_condition.append(category[2])
  if (val_predictions_sbp[i] >= 180 or val_predictions_dbp[i] >= 110):
    health_condition.append(category[2])

# %%
health_condition = np.array(health_condition)
print(health_condition)
# Out:
# ['Normal' 'Prehypertension' 'Hypertension' ... 'Hypertension'
#  'Hypertension' 'Hypertension']

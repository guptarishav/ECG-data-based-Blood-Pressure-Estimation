# %%
import zipfile as zf
files = zf.ZipFile("archive.zip", 'r')
files.extractall('directory to extract')
files.close()

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import glob
import os
import matplotlib.pyplot as plt

# %%
# importing libraries
import numpy as np # For numerical computation
import pandas as pd # Data manipulation
import seaborn as sns # plotting
import scipy.io # reading matlab files in python
from scipy import signal #signal processing
from scipy.fftpack import fft, dct #signal processing

from sklearn.linear_model import LinearRegression #linear regression model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, train_test_split # cross validation split
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pyplot as plt # For plotting graphs(Visualization)

import os # system-wide functions

# %%
sample_file = scipy.io.loadmat(f'archive/part_1.mat')
print(f'sample_file Data type: {type(sample_file)}')
print(f'sample_file keys:\n{sample_file.keys()}')
# Out:
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])

# %%
# Loading a sample .mat file to understand the data dimensions
test_sample = scipy.io.loadmat(f'archive/part_1.mat')['p']
print(f'test_sample Data type: {type(test_sample)}')
print(f'test_sample shape/dimensions: {test_sample.shape}')
# Out:
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)

# %%
print(f"Total Samples: {len(test_sample[0])}")
print(f"Number of readings in each sample(column): {len(test_sample[0][0])}")
print(f"Number of samples in each reading(ECG): {len(test_sample[0][0][2])}")

temp_mat = test_sample[0, 999]
temp_length = temp_mat.shape[1]
sample_size = 125


print(temp_length)
print((int)(temp_length/sample_size))
# Out:
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 61000
# 9000
# 72

# %%
temp_mat.shape
# Out:
# (3, 9000)

# %%
sample_size = 125
ppg = []
for i in range(1000):
    temp_mat = test_sample[0, i]
    temp_length = temp_mat.shape[1]
    for j in range((int)(temp_length/sample_size)):
        temp_ppg = temp_mat[0, j*sample_size:(j+1)*sample_size]
        ppg.append(temp_ppg)

# %%
ecg = []
bp = []
size = 125 #sample size

for i in range(1000):
    temp_mat = test_sample[0, i]
    temp_length = temp_mat.shape[1]
    for j in range((int)(temp_length/sample_size)):
        temp_ecg = temp_mat[2, j*size:(j+1)*size]
        temp_bp = temp_mat[1, j*size:(j+1)*size]
        
        max_value = max(temp_bp)
        min_value = min(temp_bp)
        ecg.append(temp_ecg)
        bp.append(temp_bp)

# %%
for i in range(2,12):
  sample_file = scipy.io.loadmat(f'archive/part_'+str(i)+'.mat')
  print(f'sample_file Data type: {type(sample_file)}')
  print(f'sample_file keys:\n{sample_file.keys()}')
  # Loading a sample .mat file to understand the data dimensions
  test_sample = scipy.io.loadmat(f'archive/part_'+str(i)+'.mat')['p']
  print(f'test_sample Data type: {type(test_sample)}')
  print(f'test_sample shape/dimensions: {test_sample.shape}')
  print(f"Total Samples: {len(test_sample[0])}")
  print(f"Number of readings in each sample(column): {len(test_sample[0][0])}")
  print(f"Number of samples in each reading(ECG): {len(test_sample[0][0][2])}")

  temp_mat = test_sample[0, 999]
  temp_length = temp_mat.shape[1]
  sample_size = 125


  print(temp_length)
  print((int)(temp_length/sample_size))
  for i in range(1000):
      temp_mat = test_sample[0, i]
      temp_length = temp_mat.shape[1]
      for j in range((int)(temp_length/sample_size)):
          temp_ppg = temp_mat[0, j*sample_size:(j+1)*sample_size]
          ppg.append(temp_ppg)
  for i in range(1000):
      temp_mat = test_sample[0, i]
      temp_length = temp_mat.shape[1]
      for j in range((int)(temp_length/sample_size)):
          temp_ecg = temp_mat[2, j*size:(j+1)*size]
          temp_bp = temp_mat[1, j*size:(j+1)*size]
          ecg.append(temp_ecg)
          bp.append(temp_bp)
# Out:
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 6000
# 61000
# 488
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 65000
# 64000
# 512
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 57000
# 1000
# 8
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 69000
# 22000
# 176
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 22000
# 12000
# 96
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 5000
# 5000
# 40
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 1000
# 1000
# 8
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 43000
# 2000
# 16
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 21000
# 54000
# 432
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 6000
# 10000
# 80

# %%
# Reshaping the ecg, ppg and bp signal data into column vectors
ppg, ecg, bp = np.array(ppg).reshape(-1,1), np.array(ecg).reshape(-1,1), np.array(bp).reshape(-1,1)
print(f'PPG_shape: {ppg.shape}\n ECG_shape: {ecg.shape}\n BP_shape: {bp.shape}')
# Out:
# PPG_shape: (308989000, 1)
#  ECG_shape: (308989000, 1)
#  BP_shape: (308989000, 1)

# %%
##plotting sample ppg, ecg and bp signals
##using a sample size of 500
fig, ax = plt.subplots(3,1, figsize=(9,12), sharex=True)

ax[0].set_title('PPG graph', fontsize=16)
ax[0].set_ylabel('Signal Value')
ax[0].plot(ppg[:500])

ax[1].set_title('ECG graph', fontsize=16)
ax[1].set_ylabel('Signal Value')
ax[1].plot(ecg[:500])

ax[2].set_title('Blood Pressure (BP) graph', fontsize=16)
ax[2].set_ylabel('Signal Value')
ax[2].set_xlabel('Sample size')
ax[2].plot(bp[:500])

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


def run():
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz

    # Sample rate and desired cutoff frequencies (in Hz).
    fs = 500.0
    lowcut = 0.1
    highcut = 50.0
    y = butter_bandpass_filter(ecg, lowcut, highcut, fs, order=2)
    plt.plot(y[:500])
    plt.xlabel('sample size')
    plt.grid(True)

    plt.show()


run()

# %%
fs = 500.0
lowcut = 0.1
highcut = 50.0
ecg_new=butter_bandpass_filter(ecg, lowcut, highcut, fs, order=2)

# %%
fig, ax = plt.subplots(2,1, figsize=(9,12), sharex=True)

ax[0].set_title('ecg_new', fontsize=16)
ax[0].set_ylabel('Signal Value')
ax[0].plot(ecg_new[:500])

ax[1].set_title('ECG graph', fontsize=16)
ax[1].set_ylabel('Signal Value')
ax[1].plot(ecg[:500])

# %%
pip install neurokit2
# Out:
# Requirement already satisfied: neurokit2 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.2.0)
# Requirement already satisfied: pandas in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.4.3)
# Requirement already satisfied: matplotlib in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (3.5.2)
# Requirement already satisfied: numpy in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.23.0)
# Requirement already satisfied: scipy in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.8.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neurokit2) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.0->neurokit2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.0->neurokit2) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (4.34.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->neurokit2) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->neurokit2) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\om\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.signal
import scipy.stats
import neurokit2 as nk

# %%
ecg_new.shape
# Out:
# (308989000, 1)

# %%
ecg_new=ecg_new.reshape(len(ecg_new))

# %%
bp=bp.reshape(len(bp))

# %%
ecg_new.shape
# Out:
# (308989000,)

# %%
bp.shape
# Out:
# (308989000,)

# %%
_, rpeaks = nk.ecg_peaks(ecg_new, sampling_rate=50)

# %%
rpeaks
# Out:
# {'ECG_R_Peaks': array([       38,       101,       162, ..., 159169498, 159169561,
#         159169625]),
#  'sampling_rate': 50}

# %%
len(rpeaks.values())
# Out:
# 2

# %%
a=[]
for i in rpeaks.values():
  a.append(i)

# %%
a
# Out:
# [array([       38,       101,       162, ..., 159169498, 159169561,
#         159169625]),
#  50]

# %%
peak=[]
peak=a[0]

# %%
peak
# Out:
# array([       38,       101,       162, ..., 159169498, 159169561,
#        159169625])

# %%
len(peak)
# Out:
# 2066605

# %%
ecg_new.shape
# Out:
# (308989000,)

# %%
all_peaks=[]
corr_bp=[]
i=0
while i+3<len(peak):
  j=peak[i]
  k=peak[i+3]
  temp=ecg_new[j:k+1]
  b=bp[j:k+1]
  all_peaks.append(temp)
  corr_bp.append(b)
  i+=4

# %%
len(all_peaks)
# Out:
# 516651

# %%
len(corr_bp)
# Out:
# 516651

# %%
new_data=np.array(all_peaks)

# %%
plt.plot(all_peaks[1])

# %%
plt.plot(corr_bp[1])

# %%
from scipy import signal
from scipy.fft import fft, fftfreq, fftshift
import scipy.fft
f=scipy.signal.resample(all_peaks[1], 120)
b=scipy.signal.resample(corr_bp[1], 120)

# %%
plt.plot(f)

# %%
f_peak=[]
f_bp=[]
for i in range(len(all_peaks)):
    f=scipy.signal.resample(all_peaks[i], 120)
    b=scipy.signal.resample(corr_bp[i], 120)
    f_peak.append(f);
    f_bp.append(b)

# %%
f_peak=np.array(f_peak)
f_bp=np.array(f_bp)

# %%
f_peak.shape
# Out:
# (516651, 120)

# %%
f_bp.shape
# Out:
# (516651, 120)

# %%
peak_sbp=[]
peak_dbp=[]
for i in f_bp:
  peak_sbp.append(max(i))
  peak_dbp.append(min(i))

# %%
peak_sbp=np.array(peak_sbp)
peak_dbp=np.array(peak_dbp)

# %%
peak_sbp.shape
# Out:
# (516651,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f_peak,peak_sbp, test_size=0.33)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import KFold, train_test_split # cross validation split
from sklearn.metrics import mean_squared_error

# %%
def rmse(y_true, y_pred):
    """Computes the Root Mean Squared Error (RMSE)."""
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %%
def Model(input_dim, activation, num_class):
    model = Sequential()

    model.add(Dense(1024, input_dim = input_dim))
    model.add(Activation(activation))
    model.add(Dropout(0.5))

    model.add(Dense(512)) 
    model.add(Activation(activation))
    model.add(Dropout(0.5))

    model.add(Dense(64))    
    model.add(Activation(activation))
    model.add(Dropout(0.25))

    model.add(Dense(num_class))    
    model.add(Activation('linear'))
    
    model.compile(loss='Huber',
                  optimizer=optimizers.Adam(lr = 0.001),
                  metrics=['MeanAbsoluteError']
                 )
    return model

# %%
input_dim = X_train.shape[1]
activation = 'relu'
classes = 1
model = Model(input_dim=input_dim, activation=activation, num_class=classes)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              123904
#
#  activation (Activation)     (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 64)                32832
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 681,601
# Trainable params: 681,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
history = model.fit(X_train, # using the first 1million rows for speed.
                    y_train.squeeze(),
                    epochs=100,
                    batch_size=128,
                    verbose = 1
                   )
# Out:
# Epoch 1/100
# 2705/2705 [==============================] - 25s 8ms/step - loss: 22.3763 - mean_absolute_error: 22.8715
# Epoch 2/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 20.9116 - mean_absolute_error: 21.4066
# Epoch 3/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 20.6838 - mean_absolute_error: 21.1788
# Epoch 4/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 20.3795 - mean_absolute_error: 20.8745
# Epoch 5/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 20.1334 - mean_absolute_error: 20.6283
# Epoch 6/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 19.8049 - mean_absolute_error: 20.2995
# Epoch 7/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 19.4829 - mean_absolute_error: 19.9776
# Epoch 8/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 19.1881 - mean_absolute_error: 19.6826
# Epoch 9/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 18.8470 - mean_absolute_error: 19.3413
# Epoch 10/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 18.5162 - mean_absolute_error: 19.0105
# Epoch 11/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 18.2781 - mean_absolute_error: 18.7722
# Epoch 12/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 18.0169 - mean_absolute_error: 18.5109
# Epoch 13/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 17.7690 - mean_absolute_error: 18.2629
# Epoch 14/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 17.5817 - mean_absolute_error: 18.0754
# Epoch 15/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 17.3676 - mean_absolute_error: 17.8612
# Epoch 16/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 17.1535 - mean_absolute_error: 17.6471
# Epoch 17/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 16.9620 - mean_absolute_error: 17.4556
# Epoch 18/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 16.8273 - mean_absolute_error: 17.3206
# Epoch 19/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 16.6315 - mean_absolute_error: 17.1249
# Epoch 20/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 16.5259 - mean_absolute_error: 17.0193
# Epoch 21/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 16.3821 - mean_absolute_error: 16.8755
# Epoch 22/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 16.1233 - mean_absolute_error: 16.6163
# Epoch 23/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.9676 - mean_absolute_error: 16.4606
# Epoch 24/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.8606 - mean_absolute_error: 16.3537
# Epoch 25/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.6943 - mean_absolute_error: 16.1871
# Epoch 26/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.5607 - mean_absolute_error: 16.0535
# Epoch 27/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.4306 - mean_absolute_error: 15.9233
# Epoch 28/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.2617 - mean_absolute_error: 15.7545
# Epoch 29/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.1309 - mean_absolute_error: 15.6235
# Epoch 30/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 15.0837 - mean_absolute_error: 15.5761
# Epoch 31/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.9997 - mean_absolute_error: 15.4923
# Epoch 32/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.9051 - mean_absolute_error: 15.3976
# Epoch 33/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.8312 - mean_absolute_error: 15.3236
# Epoch 34/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.7385 - mean_absolute_error: 15.2308
# Epoch 35/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.7152 - mean_absolute_error: 15.2075
# Epoch 36/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.6135 - mean_absolute_error: 15.1058
# Epoch 37/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.5601 - mean_absolute_error: 15.0523
# Epoch 38/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.4801 - mean_absolute_error: 14.9724
# Epoch 39/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.4245 - mean_absolute_error: 14.9166
# Epoch 40/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.3636 - mean_absolute_error: 14.8558
# Epoch 41/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.2470 - mean_absolute_error: 14.7390
# Epoch 42/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 14.2106 - mean_absolute_error: 14.7026
# Epoch 43/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.1515 - mean_absolute_error: 14.6434
# Epoch 44/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.0965 - mean_absolute_error: 14.5883
# Epoch 45/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 14.0025 - mean_absolute_error: 14.4943
# Epoch 46/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 13.9390 - mean_absolute_error: 14.4308
# Epoch 47/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 13.8820 - mean_absolute_error: 14.3737
# Epoch 48/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.8286 - mean_absolute_error: 14.3203
# Epoch 49/100
# 2705/2705 [==============================] - 24s 9ms/step - loss: 13.7465 - mean_absolute_error: 14.2381
# Epoch 50/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.7114 - mean_absolute_error: 14.2032
# Epoch 51/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 13.6387 - mean_absolute_error: 14.1302
# Epoch 52/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.5848 - mean_absolute_error: 14.0764
# Epoch 53/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.5084 - mean_absolute_error: 13.9997
# Epoch 54/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.4946 - mean_absolute_error: 13.9861
# Epoch 55/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.4287 - mean_absolute_error: 13.9200
# Epoch 56/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 13.3742 - mean_absolute_error: 13.8655
# Epoch 57/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.3361 - mean_absolute_error: 13.8274
# Epoch 58/100
# 2705/2705 [==============================] - 24s 9ms/step - loss: 13.2676 - mean_absolute_error: 13.7588
# Epoch 59/100
# 2705/2705 [==============================] - 24s 9ms/step - loss: 13.2177 - mean_absolute_error: 13.7088
# Epoch 60/100
# 2705/2705 [==============================] - 24s 9ms/step - loss: 13.1692 - mean_absolute_error: 13.6604
# Epoch 61/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.1185 - mean_absolute_error: 13.6096
# Epoch 62/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 13.0805 - mean_absolute_error: 13.5713
# Epoch 63/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 13.0242 - mean_absolute_error: 13.5152
# Epoch 64/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.9862 - mean_absolute_error: 13.4771
# Epoch 65/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.9307 - mean_absolute_error: 13.4215
# Epoch 66/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.8730 - mean_absolute_error: 13.3637
# Epoch 67/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.8070 - mean_absolute_error: 13.2976
# Epoch 68/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.7603 - mean_absolute_error: 13.2509
# Epoch 69/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.7253 - mean_absolute_error: 13.2159
# Epoch 70/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.6826 - mean_absolute_error: 13.1731
# Epoch 71/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 12.6414 - mean_absolute_error: 13.1320
# Epoch 72/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.5899 - mean_absolute_error: 13.0802
# Epoch 73/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 12.5480 - mean_absolute_error: 13.0384
# Epoch 74/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 12.5163 - mean_absolute_error: 13.0067
# Epoch 75/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.4824 - mean_absolute_error: 12.9727
# Epoch 76/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.4318 - mean_absolute_error: 12.9219
# Epoch 77/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.3945 - mean_absolute_error: 12.8847
# Epoch 78/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.3468 - mean_absolute_error: 12.8368
# Epoch 79/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.3217 - mean_absolute_error: 12.8119
# Epoch 80/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.2788 - mean_absolute_error: 12.7688
# Epoch 81/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.2482 - mean_absolute_error: 12.7382
# Epoch 82/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.2513 - mean_absolute_error: 12.7414
# Epoch 83/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.2064 - mean_absolute_error: 12.6964
# Epoch 84/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.1444 - mean_absolute_error: 12.6343
# Epoch 85/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.1193 - mean_absolute_error: 12.6089
# Epoch 86/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.0926 - mean_absolute_error: 12.5824
# Epoch 87/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.0779 - mean_absolute_error: 12.5677
# Epoch 88/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 12.0290 - mean_absolute_error: 12.5188
# Epoch 89/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.9946 - mean_absolute_error: 12.4843
# Epoch 90/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.9788 - mean_absolute_error: 12.4683
# Epoch 91/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.9567 - mean_absolute_error: 12.4463
# Epoch 92/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.9339 - mean_absolute_error: 12.4236
# Epoch 93/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.8958 - mean_absolute_error: 12.3853
# Epoch 94/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.8641 - mean_absolute_error: 12.3537
# Epoch 95/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.8296 - mean_absolute_error: 12.3189
# Epoch 96/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.8090 - mean_absolute_error: 12.2986
# Epoch 97/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.7918 - mean_absolute_error: 12.2812
# Epoch 98/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.7587 - mean_absolute_error: 12.2479
# Epoch 99/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.7150 - mean_absolute_error: 12.2044
# Epoch 100/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 11.7082 - mean_absolute_error: 12.1974

# %%
#Predicting on the test set using the nn(neural network) model
val_predictions_sbp = model.predict(X_test)
error = rmse(y_test, val_predictions_sbp)
print(f'Neural Net RMSE: {error}')
# Out:
# 5328/5328 [==============================] - 14s 2ms/step
# Neural Net RMSE: 15.186525424780317

# %%
plt.title('Train loss against mean_absolute_error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.legend(['Loss', 'Mean_absolute_error'])

# %%
# Visualize predicted BP and the True BP
plt.title("===True SBP values Vs Predicted SBP values===")
plt.xlabel('Number of samples taken')
plt.ylabel('SBP values')
plt.plot(y_test[:100]) #only plotting 100 samples
plt.plot(val_predictions_sbp[:100])
plt.legend(['True_SBP', 'Predicted_SBP'])

# %% [markdown]
# #DBP

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f_peak,peak_dbp, test_size=0.33)

# %%
input_dim = X_train.shape[1]
activation = 'relu'
classes = 1
model = Model(input_dim=input_dim, activation=activation, num_class=classes)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1024)              123904
#
#  activation_4 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 64)                32832
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 681,601
# Trainable params: 681,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, # using the first 1million rows for speed.
                    y_train.squeeze(),
                    epochs=100,
                    batch_size=128,
                    verbose = 1
                   )
# Out:
# Epoch 1/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 10.8784 - mean_absolute_error: 11.3683
# Epoch 2/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 10.1925 - mean_absolute_error: 10.6820
# Epoch 3/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 9.8756 - mean_absolute_error: 10.3648
# Epoch 4/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 9.4688 - mean_absolute_error: 9.9575
# Epoch 5/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 9.2105 - mean_absolute_error: 9.6988
# Epoch 6/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 9.0221 - mean_absolute_error: 9.5100
# Epoch 7/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 8.8145 - mean_absolute_error: 9.3021
# Epoch 8/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 8.6449 - mean_absolute_error: 9.1322
# Epoch 9/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 8.4732 - mean_absolute_error: 8.9601
# Epoch 10/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 8.3592 - mean_absolute_error: 8.8461
# Epoch 11/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 8.2382 - mean_absolute_error: 8.7246
# Epoch 12/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 8.1417 - mean_absolute_error: 8.6280
# Epoch 13/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 8.0333 - mean_absolute_error: 8.5195
# Epoch 14/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.9253 - mean_absolute_error: 8.4112
# Epoch 15/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.8245 - mean_absolute_error: 8.3101
# Epoch 16/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.6834 - mean_absolute_error: 8.1689
# Epoch 17/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.5981 - mean_absolute_error: 8.0834
# Epoch 18/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.5129 - mean_absolute_error: 7.9980
# Epoch 19/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.4284 - mean_absolute_error: 7.9131
# Epoch 20/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.3525 - mean_absolute_error: 7.8371
# Epoch 21/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.2566 - mean_absolute_error: 7.7409
# Epoch 22/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.1973 - mean_absolute_error: 7.6814
# Epoch 23/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.1388 - mean_absolute_error: 7.6227
# Epoch 24/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.0964 - mean_absolute_error: 7.5802
# Epoch 25/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 7.0355 - mean_absolute_error: 7.5190
# Epoch 26/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.9861 - mean_absolute_error: 7.4696
# Epoch 27/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.9426 - mean_absolute_error: 7.4261
# Epoch 28/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.8886 - mean_absolute_error: 7.3717
# Epoch 29/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.8603 - mean_absolute_error: 7.3434
# Epoch 30/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.8113 - mean_absolute_error: 7.2943
# Epoch 31/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.7857 - mean_absolute_error: 7.2686
# Epoch 32/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.7327 - mean_absolute_error: 7.2154
# Epoch 33/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.6903 - mean_absolute_error: 7.1727
# Epoch 34/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 6.6480 - mean_absolute_error: 7.1303
# Epoch 35/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 6.6037 - mean_absolute_error: 7.0860
# Epoch 36/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 6.5716 - mean_absolute_error: 7.0539
# Epoch 37/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.5400 - mean_absolute_error: 7.0220
# Epoch 38/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.5147 - mean_absolute_error: 6.9966
# Epoch 39/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.4867 - mean_absolute_error: 6.9685
# Epoch 40/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.4562 - mean_absolute_error: 6.9378
# Epoch 41/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.4320 - mean_absolute_error: 6.9136
# Epoch 42/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 6.3963 - mean_absolute_error: 6.8777
# Epoch 43/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.3684 - mean_absolute_error: 6.8498
# Epoch 44/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.3283 - mean_absolute_error: 6.8093
# Epoch 45/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.3116 - mean_absolute_error: 6.7926
# Epoch 46/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.2756 - mean_absolute_error: 6.7567
# Epoch 47/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.2464 - mean_absolute_error: 6.7274
# Epoch 48/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.2248 - mean_absolute_error: 6.7052
# Epoch 49/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.2013 - mean_absolute_error: 6.6816
# Epoch 50/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.1822 - mean_absolute_error: 6.6624
# Epoch 51/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.1671 - mean_absolute_error: 6.6477
# Epoch 52/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.1309 - mean_absolute_error: 6.6112
# Epoch 53/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.1135 - mean_absolute_error: 6.5936
# Epoch 54/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.0900 - mean_absolute_error: 6.5701
# Epoch 55/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.0831 - mean_absolute_error: 6.5632
# Epoch 56/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.0436 - mean_absolute_error: 6.5234
# Epoch 57/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 6.0394 - mean_absolute_error: 6.5190
# Epoch 58/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 6.0183 - mean_absolute_error: 6.4979
# Epoch 59/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.9864 - mean_absolute_error: 6.4657
# Epoch 60/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.9697 - mean_absolute_error: 6.4489
# Epoch 61/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.9560 - mean_absolute_error: 6.4352
# Epoch 62/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.9450 - mean_absolute_error: 6.4240
# Epoch 63/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.9122 - mean_absolute_error: 6.3911
# Epoch 64/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.9074 - mean_absolute_error: 6.3863
# Epoch 65/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 5.8864 - mean_absolute_error: 6.3652
# Epoch 66/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.8647 - mean_absolute_error: 6.3434
# Epoch 67/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.8686 - mean_absolute_error: 6.3475
# Epoch 68/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.8413 - mean_absolute_error: 6.3197
# Epoch 69/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.8267 - mean_absolute_error: 6.3051
# Epoch 70/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.8138 - mean_absolute_error: 6.2922
# Epoch 71/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.7946 - mean_absolute_error: 6.2728
# Epoch 72/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.7865 - mean_absolute_error: 6.2646
# Epoch 73/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.7654 - mean_absolute_error: 6.2434
# Epoch 74/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.7551 - mean_absolute_error: 6.2331
# Epoch 75/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.7451 - mean_absolute_error: 6.2229
# Epoch 76/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.7357 - mean_absolute_error: 6.2134
# Epoch 77/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 5.7312 - mean_absolute_error: 6.2090
# Epoch 78/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 5.7185 - mean_absolute_error: 6.1961
# Epoch 79/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.6922 - mean_absolute_error: 6.1698
# Epoch 80/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.6938 - mean_absolute_error: 6.1712
# Epoch 81/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.6845 - mean_absolute_error: 6.1619
# Epoch 82/100
# 2705/2705 [==============================] - 18s 7ms/step - loss: 5.6759 - mean_absolute_error: 6.1531
# Epoch 83/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.6728 - mean_absolute_error: 6.1500
# Epoch 84/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 5.6631 - mean_absolute_error: 6.1402
# Epoch 85/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 5.6501 - mean_absolute_error: 6.1274
# Epoch 86/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 5.6386 - mean_absolute_error: 6.1158
# Epoch 87/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.6269 - mean_absolute_error: 6.1040
# Epoch 88/100
# 2705/2705 [==============================] - 19s 7ms/step - loss: 5.6142 - mean_absolute_error: 6.0913
# Epoch 89/100
# 2705/2705 [==============================] - 20s 7ms/step - loss: 5.6151 - mean_absolute_error: 6.0922
# Epoch 90/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 5.6094 - mean_absolute_error: 6.0865
# Epoch 91/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 5.5933 - mean_absolute_error: 6.0703
# Epoch 92/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 5.5881 - mean_absolute_error: 6.0650
# Epoch 93/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 5.5817 - mean_absolute_error: 6.0584
# Epoch 94/100
# 2705/2705 [==============================] - 21s 8ms/step - loss: 5.5682 - mean_absolute_error: 6.0450
# Epoch 95/100
# 2705/2705 [==============================] - 20s 8ms/step - loss: 5.5636 - mean_absolute_error: 6.0405
# Epoch 96/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 5.5719 - mean_absolute_error: 6.0488
# Epoch 97/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 5.5560 - mean_absolute_error: 6.0329
# Epoch 98/100
# 2705/2705 [==============================] - 23s 8ms/step - loss: 5.5473 - mean_absolute_error: 6.0240
# Epoch 99/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 5.5400 - mean_absolute_error: 6.0168
# Epoch 100/100
# 2705/2705 [==============================] - 22s 8ms/step - loss: 5.5327 - mean_absolute_error: 6.0092

# %%
#Predicting on the test set using the nn(neural network) model
val_predictions_dbp = model.predict(X_test)
error = rmse(y_test, val_predictions_dbp)
print(f'Neural Net RMSE: {error}')
# Out:
# 5328/5328 [==============================] - 12s 2ms/step
# Neural Net RMSE: 9.09528037081269

# %%
plt.title('Train loss against mean_absolute_error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.legend(['Loss', 'Mean_absolute_error'])

# %%
# Visualize predicted BP and the True BP
plt.title("===True DBP values Vs Predicted DBP values===")
plt.xlabel('Number of samples taken')
plt.ylabel('DBP values')
plt.plot(y_test[:100]) #only plotting 100 samples
plt.plot(val_predictions_dbp[:100])
plt.legend(['True_DBP', 'Predicted_dBP'])

# %%
health_condition = []
category = ["Normal", "Prehypertension", "Hypertension"]
for i in range(len(val_predictions_sbp)):
  if (val_predictions_sbp[i] <= 90 or val_predictions_dbp[i] <= 60):
    health_condition.append(category[0])
  if ((val_predictions_sbp[i] >= 90 and val_predictions_sbp[i] < 120) and (val_predictions_dbp[i] >= 60 and val_predictions_dbp[i] < 79)):
    health_condition.append(category[0])
  if ((val_predictions_sbp[i] >= 120 and val_predictions_sbp[i] < 140) or (val_predictions_dbp[i] >= 80 and val_predictions_dbp[i] < 90)):
    health_condition.append(category[1])
  if ((val_predictions_sbp[i] >= 140 and val_predictions_sbp[i] < 160) or (val_predictions_dbp[i] >= 90 and val_predictions_dbp[i] < 100)):
    health_condition.append(category[2])
  if (val_predictions_sbp[i] >= 160 or val_predictions_dbp[i] >= 100):
    health_condition.append(category[2])
  if (val_predictions_sbp[i] >= 140 and val_predictions_dbp[i] < 90):
    health_condition.append(category[2])
  if (val_predictions_sbp[i] >= 180 or val_predictions_dbp[i] >= 110):
    health_condition.append(category[2])

# %%
health_condition = np.array(health_condition)
print(health_condition)
# Out:
# ['Hypertension' 'Hypertension' 'Hypertension' ... 'Prehypertension'
#  'Normal' 'Prehypertension']
